# %% [markdown]
# # Final results for the working memory dataset

# %%
import os
import numpy as np
import seaborn as sns # for plots
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from scipy import stats as sps # to calcualte confidence intervals, etc
from adjustText import adjust_text # to adjust the text labels in the plots (pip install adjustText)

from statsmodels.stats.anova import AnovaRM # perform F test

# %%
# setting directories
base_dir = '/Volumes/diedrichsen_data$/data/FunctionalFusion'
conn_dir = '/Volumes/diedrichsen_data$/data/Cerebellum/connectivity'
if not Path(base_dir).exists():
    base_dir = '/srv/diedrichsen/data/FunctionalFusion'
    conn_dir = '/srv/diedrichsen/data/Cerebellum/connectivity'
atlas_dir = base_dir + '/Atlases'

# %% [markdown]
# <font color = 'grey'>Defining functions specific to this dataset

# %%
# Functions
# prepare dataframe for plotting
def prep_df(dataframe, agg_kw = {}, groupby = "cond_name"):
    """
    prepare the region dataframe to do the scatter plot
    gets the mean across subjects (data point) and std of residuals
    THIS ONLY WORKS FOR WM dataset
    Args:
        dataframe (pd.DataFrame) - dataframe with residuals info 
        agg_kw (dict) - dictionary determining info for dataframe aggregation
        Example agg_kw: {'load': 'first',
                         'phase': 'first',
                         'recall': 'first',
                         'X': np.mean,
                         'Y': np.mean}
    Returns:
    g_df (pd.DataFrame) - dataframe ready for putting into the scatterplot function
    """
    # group by condition
    grouped = dataframe.groupby([groupby])
    g_df = grouped.agg(agg_kw)
    
    g_std = grouped.std(numeric_only=True)
    g_df["Y_CI"] = grouped.Y.apply(sps.sem) * 1.96
    g_df["X_CI"] = grouped.X.apply(sps.sem)*1.96
    g_df['err'] = g_std['res']
    
    
    return g_df

# add text labels to points
def annotate(dataframe, text_size = 'small', text_weight = 'regular', labels = "load"):
    """
    annotate data points in the scatterplot
    Args:
    dataframe (pd.DataFrame)
    text_size (str) 
    text_weight (str)
    labels (str) - column of the dataframe that is to be used as label
    """
    texts = []
    for i in range(dataframe.shape[0]):   
        text = plt.text(
                        dataframe.X[i]+0.001, 
                        dataframe.Y[i], 
                        s = dataframe[labels][i],
                        horizontalalignment='left', 
                        size=text_size, 
                        weight=text_weight
                        )
        texts.append(text)

    adjust_text(texts) # make sure you have installed adjust_text

# plotting:
def make_plot(dataframe, hue = "phase", style = "recall", label = "load", height = 4, aspect = 1):
    """
    make scatterplot
    uses FacetGrid 
    Args: 
    dataframe (pd.DataFrame) - output from prep_df
    hue (str)      - column name to be used to determine color
    style (str)    - column name to be used to determine shape of the marker
    label (str)    - column name to be used to determine the label of the data points
    height (int)   - int to determine the height of the plot
    aspect (float) - floating number to determine the aspect ratio of the plot
    """
    g = sns.FacetGrid(dataframe,  height=height, aspect=aspect)
    # do the scatter plot
    g.map_dataframe(sns.scatterplot, x="X", y="Y", 
                                    style = style, hue = hue, s = 100)
    g.add_legend()

    # fit the regression on top of the scatterplot
    g.map_dataframe(sns.regplot, x="X", y="Y", 
                        fit_reg=True, 
                        scatter_kws={"s": 0}, # size is set to 0 so that it doesn't cover the markers created in the scatterplot step 
                        line_kws={'label':"Linear Reg", "color": 'grey'})

    # put the errorbars in 
    g.map(plt.errorbar, x = df_preped['X'], 
                        y = df_preped['Y'], 
                        yerr = df_preped['err'],
                        elinewidth=1, 
                        fmt='none', # no marker will be used when plotting the error bars
                        color='grey', 
                        ecolor='0.9'
                )
    # set labels
    g.set_xlabels('Cortical Activation (a.u.)')
    g.set_ylabels('Cerebellar Activation (a.u.)')

    # get labels for each data point
    annotate(df_preped, text_size = 'small', text_weight = 'regular', labels = label)
    return

# %% [markdown]
# ## 1. Plots and test results
# investigating linearity

# %% [markdown]
# ### 1.1 Over the whole cerebellum and cortex

# %% [markdown]
# <font color = 'grey'>Prepare the dataframe for the scatterplot

# %%
# load the dataframe for the whole 
df_path = os.path.join(conn_dir, "Demand", "sc_Demand_ses-01_whole.tsv")
df = pd.read_csv(df_path, sep="\t")

# cleaning up dataframe
df["Easy"] = (df['cond_name'] == "nback_E_face")*1
df["Hard"] = (df['cond_name'] == "nback_H_face")*2
df["level"] = df["Easy"] + df["Hard"]

# prepare df for plotting
# by setting non-numeric fields to 'first', we make sure that they are not removed from the final dataframe
agg_kw= {'material': 'first', 'task':'first', 'cond_name':'first', 'X': np.mean, 'Y': np.mean, 'res': np.mean}
df_preped = prep_df(df, groupby = "cond_name", agg_kw=agg_kw)

# print(np.sum(df['res']))

# %%
make_plot(df_preped, hue = "material", style="task", label = 'cond_name', height = 4, aspect = 1)
plt.savefig("SC_demand_WHOLE.svg")

# %% [markdown]
# Figure 1. Scatterplot showing average cerebellar activation in each condition vs the corresponding average activation in the cortex. The linear fit is shown in grey. Error bars represent the standard deviation of the residuals of the linear regression fit.

# %% [markdown]
# <font color = 'grey'> Do F-test (repeated measures ANOVA)

# %%
# need to pass on aggregate_func to aggregate over the two halved (see half column in the original dataframe)
print(AnovaRM(data=df, depvar='res',
              subject='sn', within=['cond_name'], aggregate_func = np.mean).fit())
# Out:
#                   Anova
# =========================================
#           F Value  Num DF  Den DF  Pr > F
# -----------------------------------------
# cond_name 14.3420 11.0000 396.0000 0.0000
# =========================================

# %% [markdown]
# ### 1.2 Over region of interests
# #### 1.2.1 verbal working memory contrast

# %% [markdown]
# <font color = 'grey'>Prepare the dataframe for the scatterplot

# %%
# load the dataframe for the whole 
df_path = os.path.join(conn_dir, "Demand", "sc_Demand_ses-01_Verbal2Back.tsv")
df = pd.read_csv(df_path, sep="\t")

# cleaning up dataframe
df["Easy"] = (df['cond_name'] == "nback_E_face")*1
df["Hard"] = (df['cond_name'] == "nback_H_face")*2
df["level"] = df["Easy"] + df["Hard"]

# prepare df for plotting
# by setting non-numeric fields to 'first', we make sure that they are not removed from the final dataframe
agg_kw= {'material': 'first', 'task':'first', 'cond_name':'first', 'X': np.mean, 'Y': np.mean, 'res': np.mean}
df_preped = prep_df(df, groupby = "cond_name", agg_kw=agg_kw)
df_preped

# print(np.sum(df['res']))
# Out:
#                 material    task        cond_name         X         Y  \
# cond_name
# nback_E_face        face  n_back    nback_E_face   0.287688  0.078134
# nback_E_house      house  n_back   nback_E_house   0.294370  0.073064
# nback_H_face        face  n_back    nback_H_face   0.613092  0.190823
# nback_H_house      house  n_back   nback_H_house   0.601728  0.183521
# stop_E_face         face    stop      stop_E_face  0.147178  0.040229
# stop_E_house       house    stop    stop_E_house   0.172731  0.043262
# stop_H_face         face    stop     stop_H_face   0.392716  0.126803
# stop_H_house       house    stop    stop_H_house   0.413985  0.130524
# switch_E_face       face  switch   switch_E_face   0.163805  0.043486
# switch_E_house     house  switch  switch_E_house   0.213172  0.048587
# switch_H_face       face  switch   switch_H_face   0.521925  0.151998
# switch_H_house     house  switch  switch_H_house   0.559808  0.157058
#
#                       res      Y_CI      X_CI       err
# cond_name
# nback_E_face    -0.003473  0.018298  0.051289  0.018920
# nback_E_house   -0.011340  0.017342  0.051892  0.024082
# nback_H_face     0.004578  0.024213  0.042795  0.023317
# nback_H_house    0.000844  0.022252  0.039417  0.019916
# stop_E_face      0.003207  0.018676  0.049645  0.018451
# stop_E_house    -0.000376  0.016135  0.044518  0.013197
# stop_H_face      0.013091  0.023438  0.055038  0.028744
# stop_H_house     0.011291  0.020785  0.048202  0.027993
# switch_E_face    0.003139  0.019312  0.049864  0.019043
# switch_E_house  -0.008892  0.017610  0.042142  0.015931
# switch_H_face   -0.001082  0.019342  0.048415  0.017497
# switch_H_house  -0.010987  0.024444  0.048904  0.023324

# %% [markdown]
# <font color = 'grey'> Do the scatterplot:<br>

# %%
make_plot(df_preped, hue = "material", style="task", label = 'cond_name', height = 4, aspect = 1)
plt.savefig("SC_demand_VWM.svg")

# %% [markdown]
# Figure 2.

# %% [markdown]
# <font color = 'grey'> Do F-test (repeated measures ANOVA)

# %%
print(AnovaRM(data=df, depvar='res',
              subject='sn', within=['cond_name'], aggregate_func = np.mean).fit())
# Out:
#                   Anova
# =========================================
#           F Value  Num DF  Den DF  Pr > F
# -----------------------------------------
# cond_name  4.6167 11.0000 396.0000 0.0000
# =========================================

# %% [markdown]
# ### 1.3 Using connectivity models

# %% [markdown]
# <font color = 'grey'> Model trained on MDTB, tested on MDTB:<br>

# %%
# load the dataframe for the whole 
df_path = os.path.join(conn_dir, "Demand", "sc_conn_MDTB_Demand_ses-01_Verbal2Back.tsv")
df = pd.read_csv(df_path, sep="\t")

# cleaning up dataframe
df["Easy"] = (df['cond_name'] == "nback_E_face")*1
df["Hard"] = (df['cond_name'] == "nback_H_face")*2
df["level"] = df["Easy"] + df["Hard"]

# prepare df for plotting
# by setting non-numeric fields to 'first', we make sure that they are not removed from the final dataframe
agg_kw= {'material': 'first', 'task':'first', 'cond_name':'first', 'level':'first', 'X': np.mean, 'Y': np.mean, 'res': np.mean}
df_preped = prep_df(df, groupby = "cond_name", agg_kw=agg_kw)
df_preped

# print(np.sum(df['res']))
# Out:
#                 material    task        cond_name  level         X         Y  \
# cond_name
# nback_E_face        face  n_back    nback_E_face       0  0.046870  0.078134
# nback_E_house      house  n_back   nback_E_house       0  0.043815  0.073064
# nback_H_face        face  n_back    nback_H_face       0  0.112295  0.190823
# nback_H_house      house  n_back   nback_H_house       0  0.108244  0.183521
# stop_E_face         face    stop      stop_E_face      0  0.013755  0.040229
# stop_E_house       house    stop    stop_E_house       0  0.015865  0.043262
# stop_H_face         face    stop     stop_H_face       0  0.078569  0.126803
# stop_H_house       house    stop    stop_H_house       0  0.078288  0.130524
# switch_E_face       face  switch   switch_E_face       0  0.020977  0.043486
# switch_E_house     house  switch  switch_E_house       0  0.025753  0.048587
# switch_H_face       face  switch   switch_H_face       0  0.089588  0.151998
# switch_H_house     house  switch  switch_H_house       0  0.096239  0.157058
#
#                       res      Y_CI      X_CI       err
# cond_name
# nback_E_face    -0.006642  0.018298  0.009773  0.020910
# nback_E_house   -0.006216  0.017342  0.009457  0.026905
# nback_H_face     0.004136  0.024213  0.007998  0.024393
# nback_H_house    0.003252  0.022252  0.008206  0.025113
# stop_E_face      0.006977  0.018676  0.009000  0.021002
# stop_E_house     0.006936  0.016135  0.007423  0.015663
# stop_H_face     -0.004578  0.023438  0.009749  0.029180
# stop_H_house    -0.000096  0.020785  0.009091  0.031802
# switch_E_face   -0.000973  0.019312  0.008109  0.024692
# switch_E_house  -0.003619  0.017610  0.007810  0.021579
# switch_H_face    0.003588  0.019342  0.009456  0.017106
# switch_H_house  -0.002767  0.024444  0.009729  0.024354

# %%
make_plot(df_preped, hue = "material", style="task", label = 'cond_name', height = 4, aspect = 1)
plt.xlabel("Predicted Activation (a.u.)")
plt.savefig("SC_demand_conn_VWM.svg")

# %%
print(AnovaRM(data=df, depvar='res',
              subject='sn', within=['cond_name'], aggregate_func = np.mean).fit())
# Out:
#                   Anova
# =========================================
#           F Value  Num DF  Den DF  Pr > F
# -----------------------------------------
# cond_name  1.4097 11.0000 396.0000 0.1656
# =========================================
